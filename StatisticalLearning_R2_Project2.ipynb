# %%
# 1.Find the mean of old scheme and new scheme column. (5 points)

# %%
import pandas as pd
import numpy as np
sales = pd.read_csv("data.csv")

# %%
sales
# Out:
#     SALESPERSON  Old Scheme (in thousands)  New Scheme (in thousands)
# 0             1                         57                         62
# 1             2                        103                        122
# 2             3                         59                         54
# 3             4                         75                         82
# 4             5                         84                         84
# 5             6                         73                         86
# 6             7                         35                         32
# 7             8                        110                        104
# 8             9                         44                         38
# 9            10                         82                        107
# 10           11                         67                         84
# 11           12                         64                         85
# ...

# %%
# old scheme mean
old_scheme = sales.iloc[: , 1].mean() 
old_scheme
# Out:
# 68.03333333333333

# %%
# new scheme mean
new_scheme = sales.iloc[: , 2].mean() 
new_scheme
# Out:
# 72.03333333333333

# %%
# 2. Use the five percent significance test over the data 
#    to determine the p value to check new scheme has significantly raised outputs? (10 points)

# %%
# null hypothesis: new scheme has not significantly raised outputs
# alternate hypothesis : new scheme has significantly raised outputs

from scipy.stats import ttest_ind, ttest_1samp, wilcoxon, levene, shapiro, mannwhitneyu
from statsmodels.stats.power import ttest_power

# %%
oldScheme = sales.iloc[: , 1]
newScheme = sales.iloc[: , 2]
shapiro(newScheme)
# Out:
# (0.9687567353248596, 0.5057420134544373)

# %%
levene(oldScheme,newScheme)
# Out:
# LeveneResult(statistic=1.063061539437244, pvalue=0.30679836081811235)

# %%
# H0: μ1 = μ2  ; μ2 – μ1  = 0
# HA: μ1 < μ2   ; μ2 – μ1  > 0 ; true difference of means is greater than zero.

t_statistic, p_value = ttest_1samp(newScheme - oldScheme, 0)
print(t_statistic, p_value)
# Out:
# 1.5559143823544377 0.13057553961337662

# %%
# 3. What conclusion does the test (p-value) lead to? (2.5 points)

print ("p-value=", p_value/2) # p > 0.05 => null hypothesis: new scheme has not significantly raised outputs
# Out:
# p-value= 0.06528776980668831

# %%
# 4. Suppose it has been calculated that in order for Titan to break even, 
# the average output must increase by £5000 in the scheme compared to the old scheme. 
# If this figure is alternative hypothesis, what is:
#        a) The probability of a type 1 error? (2.5 points)

#        b) What is the p- value of the hypothesis test if we test for a difference of $5000? (5 points)

#       c) Power of the test (5 points)

# %%
# probability of type 1 error
0.05
# Out:
# 0.05

# %%
#μ2 = Average sums assured by salesperson AFTER changeover.

#μ1 = Average sums assured by salesperson BEFORE changeover.

#μd = μ2 – μ1   H0: μd ≤ 5(in thousands)  HA: μd > 5(in thousands)

t_statistic, p_value = ttest_1samp(newScheme - oldScheme, 0)
print(t_statistic, p_value)
# Out:
# 1.5559143823544377 0.13057553961337662

# %%
print ("p-value=", p_value/2)
# Out:
# p-value= 0.06528776980668831

# %%
(np.mean(oldScheme) - np.mean(newScheme)) / np.sqrt(((30-1)*np.var(newScheme)+(30-1)*np.var(oldScheme)) / 30+30-2)
# Out:
# -0.12909555513169643

# %%
print(ttest_power(-0.12909555513169643, nobs=30, alpha=0.05, alternative='two-sided'))
# Out:
# 0.10506757964046301
